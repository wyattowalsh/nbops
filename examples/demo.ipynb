# %% [markdown]
# # nbops demo notebook
#
# A tiny notebook used to demonstrate `nbops stats`.

# %%
import math

def area(radius: float) -> float:
    return math.pi * radius ** 2

# %%
print(area(2.0))

# %% [markdown]
# Done.
