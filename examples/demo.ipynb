# %% [markdown]
# # nbops demo notebook
#
# A small notebook used to demonstrate inspect, lint, clean, convert, and stats.

# %%
import math

def area(radius: float) -> float:
    return math.pi * radius ** 2

# %%
print(area(2.0))

# %% [markdown]
# Done.
